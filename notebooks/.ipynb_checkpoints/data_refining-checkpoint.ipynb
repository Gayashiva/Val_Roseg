# %%
# -*- coding: utf-8 -*-# -*- c 
from __future__ import print_function
from __future__ import division
import datetime

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

import numpy as np
import pandas as pd
from copy import copy, deepcopy
import csv
from matplotlib import pyplot as plt
from datetime import datetime, timedelta
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Data Import and Cleaning
# ### Visually measured height and noting water discharges
# Height was measured manually using images from Wim's camera( 17th November 2016 to 7th April 2017 ). The images were programmed to be taken every 2 hours from 7 am to 4 pm. Typically a day had 4 data points. From the images fountain discharge was also noted using binary values.

# %%
dfheight=pd.read_csv('../data/raw/Results from Val_Roseg_Timelapse in µm per sec.csv')
dfw=pd.read_csv('../data/raw/water_dates.csv',parse_dates=['time'])

# %% [markdown]
# ### Extracted Image times from timelapse imagery

# %%
dfdates=pd.read_csv('../data/raw/image_dates.csv',parse_dates=['time'])

# %% [markdown]
# ### Importing weather data

# %%
df=pd.read_csv('../data/raw/Roseg_excel.csv')
df.columns=['doy','time','temp','rh','ws','swin','swout','lwin','lwout']

# %%
l=np.array([])
j=0
t=datetime(2016, 1, 1) + timedelta(days=322)
dfs=pd.DataFrame({'Type' : []})
for i in df['doy'].unique():
    mask=i==df['doy']
    l=np.append(l,df.loc[mask,'temp'].mean())
    dfs.loc[j,'date']=t
    dfs.loc[j,'doy']=i
    dfs.loc[j,'temp']=df.loc[mask,'temp'].mean()
    j=j+1
    t=t+timedelta(days=1)
dfs
# Out:
#      Type       date    doy       temp
# 0     NaN 2016-11-18  322.0  -0.282143
# 1     NaN 2016-11-19  323.0  -0.262083
# 2     NaN 2016-11-20  324.0  -0.759167
# 3     NaN 2016-11-21  325.0  -0.754167
# 4     NaN 2016-11-22  326.0   2.652500
# 5     NaN 2016-11-23  327.0   2.695833
# 6     NaN 2016-11-24  328.0   2.700417
# 7     NaN 2016-11-25  329.0   2.151667
# 8     NaN 2016-11-26  330.0   1.897500
# 9     NaN 2016-11-27  331.0   0.342917
# 10    NaN 2016-11-28  332.0  -1.533750
# 11    NaN 2016-11-29  333.0  -8.398333
# 12    NaN 2016-11-30  334.0 -11.064583
# 13    NaN 2016-12-01  335.0  -7.865417
# 14    NaN 2016-12-02  336.0  -5.420417
# 15    NaN 2016-12-03  337.0  -5.554583
# 16    NaN 2016-12-04  338.0 -10.017500
# 17    NaN 2016-12-05  339.0 -11.013750
# 18    NaN 2016-12-06  340.0 -11.733333
# 19    NaN 2016-12-07  341.0 -10.218333
# 20    NaN 2016-12-08  342.0  -8.350417
# 21    NaN 2016-12-09  343.0  -5.524167
# 22    NaN 2016-12-10  344.0  -3.668750
# 23    NaN 2016-12-11  345.0  -3.438333
# 24    NaN 2016-12-12  346.0  -4.384583
# 25    NaN 2016-12-13  347.0  -4.771250
# 26    NaN 2016-12-14  348.0  -7.757917
# 27    NaN 2016-12-15  349.0  -6.019583
# 28    NaN 2016-12-16  350.0  -9.030833
# 29    NaN 2016-12-17  351.0 -10.321667
# ..    ...        ...    ...        ...
# 203   NaN 2017-06-09  159.0   7.020417
# 204   NaN 2017-06-10  160.0  10.091667
# 205   NaN 2017-06-11  161.0  10.346250
# 206   NaN 2017-06-12  162.0  13.329583
# 207   NaN 2017-06-13  163.0  14.249167
# 208   NaN 2017-06-14  164.0  14.260000
# 209   NaN 2017-06-15  165.0  12.605000
# 210   NaN 2017-06-16  166.0  12.621250
# 211   NaN 2017-06-17  167.0  11.314167
# 212   NaN 2017-06-18  168.0   9.430417
# 213   NaN 2017-06-19  169.0  10.843750
# 214   NaN 2017-06-20  170.0  13.760417
# 215   NaN 2017-06-21  171.0  14.844167
# 216   NaN 2017-06-22  172.0  14.874167
# 217   NaN 2017-06-23  173.0  14.993750
# 218   NaN 2017-06-24  174.0  14.860833
# 219   NaN 2017-06-25  175.0  15.702083
# 220   NaN 2017-06-26  176.0  10.402083
# 221   NaN 2017-06-27  177.0  12.097917
# 222   NaN 2017-06-28  178.0  11.276250
# 223   NaN 2017-06-29  179.0   7.484583
# 224   NaN 2017-06-30  180.0   6.510833
# 225   NaN 2017-07-01  181.0   4.507500
# 226   NaN 2017-07-02  182.0   6.279583
# 227   NaN 2017-07-03  183.0   7.986250
# 228   NaN 2017-07-04  184.0   9.652917
# 229   NaN 2017-07-05  185.0  11.391250
# 230   NaN 2017-07-06  186.0  12.579583
# 231   NaN 2017-07-07  187.0  13.280417
# 232   NaN 2017-07-08  188.0  13.665385
#
# [233 rows x 4 columns]

# %% [markdown]
# ### Converting height in pixels to height in meters

# %%
dfheight=dfheight['Y']
dfheight=3000-dfheight
dfheight=dfheight-1164 #Subtracting additional length from camera
dfheight*=6/170 #170 pixels=6ft
dfh=pd.DataFrame(columns=['time','height','water'])
dfh['time']=dfdates['time']
dfh['water']=dfw['water']
dfh['time']=pd.to_datetime(dfh['time'],format='%Y:%m:%d %H:%M:%S')
dfh['height']=dfheight.apply(lambda x: float(x)*0.3048)
dfh=dfh.set_index('time')

# %% [markdown]
# ### Convert Kipp temperature to radiation

# %%
df['lw']=df['lwin']-df['lwout']
df['sw']=df['swin']-df['swout']
df['sw']=df['sw']/0.847+5.67e-8*pow((df['temp']+273.15),4)
df['lw']=df['lw']/0.847+5.67e-8*pow((df['temp']+273.15),4)

# %%
df['time']=df['time']/100
d=df['time']
d=d.tolist()
c=df['doy'].tolist()
for i in range(0,df.shape[0]):
    if c[i]>300:
        df.loc[i,'time']=datetime(2016, 1, 1) + timedelta(days=c[i]-1,hours=d[i])
    else:
        df.loc[i,'time']=datetime(2017, 1, 1) + timedelta(days=c[i]-1,hours=d[i])
df=df.set_index('time')
df.to_csv('../data/interim/roseg_data.csv')

# %%
for time in dfh.index:
    h=dfh.loc[str(time),'height']
    w=dfh.loc[str(time),'water']
    time=time.replace(hour=time.hour+1,minute=0,second=0)
    df.loc[str(time),'height']=h
    df.loc[str(time),'water']=w
df=df.dropna()

# %% [markdown]
# ### Final Processed Data Set

# %%
df.head()
df.to_csv('../data/interim/roseg_measurements.csv')

# %%
fig=plt.figure(figsize=(14,6))
ax=fig.add_subplot(1,2,1)
plt.plot(df[['temp']])
ax.set_ylabel('Temperature [C]')
ax=fig.add_subplot(1,2,2)
plt.plot(df[['height']])
plt.plot(df['water'])
ax.set_ylabel('Height_m')
# Out:
# Text(0,0.5,'Height_m')

# %% [markdown]
# The orange binary steps indicate fountain supply on/off

# %%
dfs=dfs.set_index('date')
dfs=dfs[0:len(df['doy'].unique())]
fig=plt.figure(figsize=(14,6))
ax=fig.add_subplot(1,2,1)
plt.plot(dfs[['temp']])
ax.set_ylabel('Temperature [C]')
ax=fig.add_subplot(1,2,2)
plt.plot(df[['height']])
plt.plot(df['water'])
ax.set_ylabel('Height_m')
# Out:
# Text(0,0.5,'Height_m')
